# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/ted-talks/data.csv

# %% [markdown]
# ## First n rows (By default 5)

# %%
df = pd.read_csv('/kaggle/input/ted-talks/data.csv')
print(df)
print(df.head(13))
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %% [markdown]
# ## Delete Null Values rows---- dropna()

# %%
df.isnull().sum()
df=df.dropna()
df
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %%
data=df.values
data[5331]
# Out:
# array(["How PhotoSynth can connect the world's images",
#        'Blaise Agüera y Arcas', 'March 2007', 6000000, 180000,
#        'https://ted.com/talks/blaise_aguera_y_arcas_how_photosynth_can_connect_the_world_s_images'],
#       dtype=object)

# %%
title=data[0][0]
title
# Out:
# 'Climate action needs new frontline leadership'

# %%
author=data[0][1]
author
# Out:
# 'Ozawa Bineshi Albert'

# %% [markdown]
# ## Author List

# %%
author=[]
for i in range(len(data)):
    author.append(data[i][1])
author
# Out:
# ['Ozawa Bineshi Albert',
#  'Sydney Iaukea',
#  'Martin Reeves',
#  'James K. Thornton',
#  'Mahendra Singhi',
#  'Rosamund Adoo-Kissi-Debrah',
#  'Iseult Gillespie',
#  'Gay Gordon-Byrne',
#  'Erin Meezan',
#  'Dwan Reece',
#  'Ian Kerner',
#  'Richard Browning',
#  'Daniel H. Pink',
#  'Lucas Joppa',
#  ' Belle and Sebastian',
#  'Mounia Akl',
#  'Yana Buhrer Tavanier',
#  'Susan Ruffo',
#  'Tim Dunn',
#  ' Let It Happen',
#  'Dave Matthews',
#  'Zoë Karl-Waithaka',
#  'Dan Kwartler',
#  'Dan Jørgensen',
#  'Lei Li',
#  'Nick Turner and Whitney Pennington Rodgers',
#  'Elizabeth Cox',
#  ' Kaz',
#  'Katie McGinty',
#  'Rachel Kyte',
#  'Katie Paterson',
#  'Emily Zobel Marshall',
#  'Deval Patrick',
#  'Rha Goddess and Deepa Purushothaman',
#  'Zac Goldsmith',
#  'Thomas W. Cronin',
#  'Gala Marija Vrbanic',
#  'Li-Huei Tsai',
#  'Emily Pilloton-Lam',
#  'Dustin Burke',
#  'Marie Brodsky',
#  'Gabrielle Walker',
#  'Reuben Jonathan Miller',
#  'Iseult Gillespie',
# ...

# %% [markdown]
# ## Total number of Authors

# %%
authorlen=len(author)
authorlen
# Out:
# 5439

# %% [markdown]
# ## Distinct Authors

# %%
authorset=len(set(author))
authorset
# Out:
# 4443

# %%
df
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %% [markdown]
# ## TALKS By Bill Gates

# %%
author=[]
for i in range(len(data)):
    if(data[i][1]=='Bill Gates'):
        print([data[i]])
# Out:
# [array(['The innovations we need to avoid a climate disaster',
#        'Bill Gates', 'March 2021', 1700000, 53000,
#        'https://ted.com/talks/bill_gates_the_innovations_we_need_to_avoid_a_climate_disaster'],
#       dtype=object)]
# [array(['How the pandemic will shape the near future', 'Bill Gates',
#        'June 2020', 4600000, 138000,
#        'https://ted.com/talks/bill_gates_how_the_pandemic_will_shape_the_near_future'],
#       dtype=object)]
# [array(['How we must respond to the coronavirus pandemic', 'Bill Gates',
#        'March 2020', 8600000, 259000,
#        'https://ted.com/talks/bill_gates_how_we_must_respond_to_the_coronavirus_pandemic'],
#       dtype=object)]
# [array(["The next outbreak? We're not ready", 'Bill Gates', 'March 2015',
#        43000000, 1300000,
#        'https://ted.com/talks/bill_gates_the_next_outbreak_we_re_not_ready'],
#       dtype=object)]
# [array(['Teachers need real feedback', 'Bill Gates', 'May 2013', 4500000,
#        135000,
# ...

# %% [markdown]
# ## Average View per video on TED Talk

# %%
views=[]
for i in range(len(data)):
    views.append(data[i][3])
sum(views)//len(views)
# Out:
# 2061954

# %% [markdown]
# ## Average Number of views for Bill Gates

# %%
views=[]
for i in range(len(data)):
    if(data[i][1]=='Bill Gates'):
        views.append(data[i][3])
average=sum(views)//len(views)
average
# Out:
# 9725000

# %% [markdown]
# ## View to Like Ratio

# %%
view_to_like=[]
for i in range(len(data)):
    view_to_like.append(data[i][3]/data[i][4])
print(view_to_like)
print("MAXIMUM -- ",max(view_to_like))
print("MINIMUM -- ",min(view_to_like))
# Out:
# [33.666666666666664, 33.4375, 34.333333333333336, 35.583333333333336, 33.333333333333336, 35.166666666666664, 34.333333333333336, 35.0, 34.73684210526316, 34.35294117647059, 33.46153846153846, 33.28125, 34.55555555555556, 35.06666666666667, 33.333333333333336, 34.888888888888886, 35.30769230769231, 34.8, 33.10344827586207, 33.333333333333336, 32.6530612244898, 33.35, 35.07692307692308, 35.111111111111114, 33.44827586206897, 33.833333333333336, 36.3, 34.1578947368421, 33.5, 34.05555555555556, 34.041666666666664, 34.25, 33.333333333333336, 33.9, 32.85870755750274, 33.77272727272727, 33.45, 33.30434782608695, 34.30434782608695, 33.333333333333336, 33.388888888888886, 34.857142857142854, 34.13636363636363, 34.41379310344828, 34.17391304347826, 31.25, 33.00330033003301, 32.857142857142854, 31.25, 32.05128205128205, 33.84615384615385, 31.914893617021278, 32.758620689655174, 34.375, 33.333333333333336, 34.15384615384615, 33.56, 33.964285714285715, 34.59090909090909, 34.206896551724135, 34.4
# ...

# %% [markdown]
# ## Add a new Column to DataSet

# %%
df['vtl_ratio'] = view_to_like

# %%
df
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %% [markdown]
# ## Top 5 TED Talks based on Views

# %%
df.sort_values(by='views',ascending=False).head()
# Out:
#                                            title            author  \
# 5436                 Do schools kill creativity?  Sir Ken Robinson
# 4084    Your body language may shape who you are         Amy Cuddy
# 2958  Inside the mind of a master procrastinator         Tim Urban
# 4765            How great leaders inspire action       Simon Sinek
# 4605                  The power of vulnerability       Brené Brown
#
#                 date     views    likes  \
# 5436   February 2006  72000000  2100000
# 4084       June 2012  64000000  1900000
# 2958   February 2016  60000000  1800000
# 4765  September 2009  57000000  1700000
# 4605       June 2010  56000000  1700000
#
#                                                    link  vtl_ratio
# 5436  https://ted.com/talks/sir_ken_robinson_do_scho...  34.285714
# 4084  https://ted.com/talks/amy_cuddy_your_body_lang...  33.684211
# 2958  https://ted.com/talks/tim_urban_inside_the_min...  33.333333
# ...

# %% [markdown]
# ## Top 10 TED Talks based on Likes

# %%
df.sort_values(by='likes',ascending=False).head(10)
# Out:
#                                                   title            author  \
# 5436                        Do schools kill creativity?  Sir Ken Robinson
# 4084           Your body language may shape who you are         Amy Cuddy
# 2958         Inside the mind of a master procrastinator         Tim Urban
# 4765                   How great leaders inspire action       Simon Sinek
# 4605                         The power of vulnerability       Brené Brown
# 3504         How to speak so that people want to listen   Julian Treasure
# 2168                     My philosophy for a happy life         Sam Berns
# 3251                 The next outbreak? We're not ready        Bill Gates
# 3017  What makes a good life? Lessons from the longe...  Robert Waldinger
# 3994  Looks aren't everything. Believe me, I'm a model.   Cameron Russell
#
#                 date     views    likes  \
# 5436   February 2006  72000000  2100000
# 4084       June 2012  64000000  1900000
# ...

# %% [markdown]
# ## Top 10 TED Talks based on VTL_Ratio/

# %%
df.sort_values(by='vtl_ratio',ascending=False).head(10)
# Out:
#                                                   title  \
# 955                A camera that can see around corners
# 905                      What's the point(e) of ballet?
# 837   How to see more and care less: The art of Geor...
# 26    Can you outsmart the fallacy that divided a na...
# 1016             The function and fashion of eyeglasses
# 3089             How computers translate human language
# 4389                            The right to understand
# 4362                           How to topple a dictator
# 5129                                         On glamour
# 1125                   Hacking bacteria to fight cancer
#
#                      author           date   views  likes  \
# 955           David Lindell  November 2019  364000  10000
# 905               Ming Luke     April 2020  364000  10000
# 837        Iseult Gillespie      June 2020  364000  10000
# 26            Elizabeth Cox  February 2022  363000  10000
# ...

# %% [markdown]
# ## TED Talk of Bill Gates

# %%
df[df['author'] == 'Bill Gates']
# Out:
#                                                   title      author  \
# 403   The innovations we need to avoid a climate dis...  Bill Gates
# 789         How the pandemic will shape the near future  Bill Gates
# 952     How we must respond to the coronavirus pandemic  Bill Gates
# 3251                 The next outbreak? We're not ready  Bill Gates
# 3878                        Teachers need real feedback  Bill Gates
# 4560          How state budgets are breaking US schools  Bill Gates
# 4824                                Innovating to zero!  Bill Gates
# 5062                   Mosquitos, malaria and education  Bill Gates
#
#                date     views    likes  \
# 403      March 2021   1700000    53000
# 789       June 2020   4600000   138000
# 952      March 2020   8600000   259000
# 3251     March 2015  43000000  1300000
# 3878       May 2013   4500000   135000
# 4560     March 2011   2100000    63000
# 4824  February 2010   8100000   245000
# ...

# %% [markdown]
# ## DESCRIBE AUTHOR

# %%
df['author'].describe()
# Out:
# count             5439
# unique            4443
# top       Alex Gendler
# freq                45
# Name: author, dtype: object

# %%
df[df['author'] == 'Alex Gendler']['views'].sum()
# Out:
# 187196000

# %%
topic = "covid"
for i in range(len(data)):
    if(topic in data[i][0].lower()):
        print(data[i])
# Out:
# ['4 ways the COVID-19 pandemic changed the way we sleep' 'Matt Walker'
#  'December 2021' 295000 8800
#  'https://ted.com/talks/matt_walker_4_ways_the_covid_19_pandemic_changed_the_way_we_sleep']
# ['How the COVID-19 vaccines were created so quickly'
#  'Kaitlyn Sadtler and Elizabeth Wayne' 'August 2021' 1300000 41000
#  'https://ted.com/talks/kaitlyn_sadtler_and_elizabeth_wayne_how_the_covid_19_vaccines_were_created_so_quickly']
# ['How COVID-19 reshaped US cities' 'Kevin J. Krizek' 'March 2021' 1500000
#  46000
#  'https://ted.com/talks/kevin_j_krizek_how_covid_19_reshaped_us_cities']
# ['How NASA invented a ventilator for COVID-19 ... in 37 days' 'Dan Goods'
#  'December 2020' 1200000 38000
#  'https://ted.com/talks/dan_goods_how_nasa_invented_a_ventilator_for_covid_19_in_37_days']
# ['How COVID-19 transformed the future of medicine' 'Daniel Kraft'
#  'September 2020' 1300000 40000
#  'https://ted.com/talks/daniel_kraft_how_covid_19_transformed_the_future_of_medicine']
# ...

# %% [markdown]
# ## Top 10 Authors with most number of TED Talks

# %%
df.groupby('author').size().sort_values(ascending =False).head(10)
# Out:
# author
# Alex Gendler        45
# Iseult Gillespie    33
# Matt Walker         18
# Alex Rosenthal      15
# Elizabeth Cox       13
# Emma Bryce          12
# Daniel Finkel       11
# Juan Enriquez       11
# Dan Finkel           9
# Hans Rosling         9
# dtype: int64

# %% [markdown]
# ## How many TED Talks are given in 2020?

# %% [markdown]
# # First we split Date

# %%
data=df.values
month=[]
year=[]
for i in range(len(data)):
    month.append(data[i][2].split(' ')[0])
    year.append(data[i][2].split(' ')[1])

# %% [markdown]
# # Add columns

# %%
df['year']=year
df['month']=month
df
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %% [markdown]
# # Total TED Talks in 2020

# %%
len(df[df['year']=='2020'])
# Out:
# 501

# %% [markdown]
# # Trend of TED Talks Frequency by Years

# %%
df.groupby('year').size().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# # Trend of TED Talks Frequency by Months

# %%
df.groupby('month').size().sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='month'>

# %%
df.groupby('author').sum()['views'].sort_values(ascending=False).head(10)
# Out:
# author
# Alex Gendler        187196000
# Sir Ken Robinson     95654000
# Bill Gates           77800000
# Simon Sinek          74800000
# Brené Brown          72000000
# Julian Treasure      64300000
# Amy Cuddy            64000000
# Tim Urban            60000000
# Iseult Gillespie     54998000
# Mia Nacamulli        44174000
# Name: views, dtype: int64

# %% [markdown]
# # Trend of TED Talks Frequency by Months (in year 2020)

# %%
df_pr=df[df['year']=='2020']
df_pr.groupby('month').size().sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# # Trend of TED Talks Frequency by Months (in year 2021)

# %%
df_pr=df[df['year']=='2019']
df_pr.groupby('month').size().sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='month'>
